# %%
import sys
sys.path.insert(1,'../functions/')
import torch
from torch import nn
import numpy as np
import data_sim
import matplotlib.pyplot as plt
import xarray as xr
#from slab_spike_model_constructor import *
from full_slab_spike_model_constructor import *

# %%
G_21 = xr.open_dataset("../dataset/G_21_subset_imputed.nc")
G_21 = G_21.to_array().values.squeeze(0)
G_21.shape
# Out:
# (3565, 102484)

# %%
real_data_index = True
n = 1000
p = 10000
p_causal = 100
if real_data_index:
    np.random.seed(seed = None)
    p_max = G_21.shape[1]
    n_max = G_21.shape[0]
    SNP_index = np.random.choice(p_max,size = p, replace = False)
    subject_index =  np.random.choice(n_max,size = n, replace = False)
    G_21_sub = G_21[np.ix_(subject_index, SNP_index)]
    print(G_21_sub.shape)
    freq_snp = G_21_sub.mean(axis = 0)/2
    sd_snp = np.sqrt(2*freq_snp*(1-freq_snp))
    G_21_sub = (G_21_sub-2*freq_snp)/sd_snp
    Xs = [G_21_sub]
    n = Xs[0].shape[0]
    p = Xs[0].shape[1]
else:
    Xs = None
# Out:
# (1000, 10000)

# %%
rho = 0.6
var = 1
n_matrix = 1
h = 0.5
beta_bias = 1
sim_class = data_sim.sim_tobit_data(n = n, p = p, p_causal = p_causal, rho = rho, var = var, n_matrix = n_matrix,h = h, bias = beta_bias, Xs = Xs, scale_lambda =None)
z, X, Xs, latent_mean, var_genetic, var_total, true_beta, y_star = sim_class.gen_data(seed = None)
data_sim.show_sim(z, latent_mean, var_total)
# Out:
# ------------------------------------
# genetic variance is 101.06420551585909
# total variance is202.1284110317182
# heritability is 0.49999999999999994
# ------------------------------------

# %%
model = linear_slab_spike(p = p, init_pi_local = 0.1, init_pi_global = 0.1, init_beta_var = 1, init_noise_var = 2,
                         gumbel_softmax_temp = 0.5, gumbel_softmax_hard = False, a= 0.1,b=3., init_c= 0.1, init_d = 3.
                         ).double()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.05)
lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=0.99)
for i in range(10000):
    loss = -model.ELBO(X.double(),y_star.double())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if i % 1000 == 0:
        lr_scheduler.step()
        print(f'At iteration {i}, the loss is {loss.item()}')
# Out:
# At iteration 0, the loss is 80006.48754006492
# At iteration 1000, the loss is 8369.75446874175
# At iteration 2000, the loss is 8264.753082091685
# At iteration 3000, the loss is 8208.666994812946
# At iteration 4000, the loss is 8178.553985330399
# At iteration 5000, the loss is 8136.406409398116
# At iteration 6000, the loss is 8122.741831343779
# At iteration 7000, the loss is 8142.011163529984
# At iteration 8000, the loss is 8096.41798202503
# At iteration 9000, the loss is 8127.425474487729

# %%
model.inference(X = X.double(), plot = True, true_beta = true_beta)
# Out:
# {'mean_h_est': 0.7766594100541719,
#  'h_est_upper': 0.8156691321745936,
#  'h_est_lower': 0.7274980067870459,
#  'mean_var_genetic': 413.8459291388434,
#  'noise_var': array(117.4851167),
#  'global_pi': 0.023019674453795203,
#  'global_pi_upper': 0.055202979102838064,
#  'global_pi_lower': 0.005334678727406787}

# %%
p_causal/p
# Out:
# 0.05

# %%
torch.mean(torch.sigmoid(model.logit_pi_local))
# Out:
# tensor(6.2103e-07, dtype=torch.float64, grad_fn=<MeanBackward0>)

# %%
print(torch.max(torch.sigmoid(model.logit_pi_local)))
print(torch.min(torch.sigmoid(model.logit_pi_local)))
# Out:
# tensor(5.2613e-06, dtype=torch.float64, grad_fn=<MaxBackward1>)
# tensor(1.3674e-07, dtype=torch.float64, grad_fn=<MinBackward1>)

# %%
model.c
# Out:
# Parameter containing:
# tensor([0.0114], dtype=torch.float64, requires_grad=True)

# %%
model.d
# Out:
# Parameter containing:
# tensor([39.6479], dtype=torch.float64, requires_grad=True)

# %%
torch.min(model.beta_mu)
# Out:
# tensor(-0.0014, dtype=torch.float64, grad_fn=<MinBackward1>)

# %%
torch.max(model.beta_mu)
# Out:
# tensor(1.5616, dtype=torch.float64, grad_fn=<MaxBackward1>)

# %%
torch.exp(model.beta_log_var)
# Out:
# tensor([3.0828, 3.0822, 3.0750,  ..., 3.0828, 3.0829, 3.0824],
#        dtype=torch.float64, grad_fn=<ExpBackward0>)

# %%
torch.mean(torch.exp(model.beta_log_var))
# Out:
# tensor(3.0795, dtype=torch.float64, grad_fn=<MeanBackward0>)
